# %%
class Car:
    def __init__(self,price):

# %%
class Backpack:
    def __init__(self,price,size):
        self.items=[]
        self.price=price
        self.size=size
        self.type="cloth"

# %%
import math


class Circle:
    def __init__(self,radius):
        self.radius=radius
    def area(self):
        return math.pi*self.radius*self.radius
    def perimeter(self):
        return 2*math.pi*self.radius
yellow_circle=Circle(5)
print(yellow_circle.area())
print(yellow_circle.perimeter())
# Out:
# 78.53981633974483
# 31.41592653589793

# %%
class Rectangle:
    def __init__(self,length,width):
        self.length=length
        self.width=width

# %%
class Movie:
    def __init__(self,topic,rating,title,producer):
        self.topic=topic
        self.title=title
        self.rating=rating
        self.producer=producer

# %%
david=Movie("biblical",10,"David","sunrise animation studios")
The_Bad_guys=Movie("action",8,"The Bad Guys","universal studios")

# %%
print(david.title)
print(david.rating)
print(david.topic)
print(david.producer)
# Out:
# David
# 10
# biblical
# sunrise animation studios

# %%
print(None)
# Out:
# None

# %%
class Math:
    def __init__(self,value):
        self.value = value
        print(self.value)
        
algebra=Math("algebra")
# Out:
# algebra

# %%
class Book:
    def __init__ (self, title="unknown"):
        self.title = title
        print(f"When an instance of Book is created with the title '{self.title}', this message is printed.")
    def get_title(self):
        return self.title


my_book=Book("The Great Gatsby")
maths_book=Book("Advanced Mathematics")
old_book=Book()
print(my_book.get_title())
my_book.title="1984"
print(my_book.get_title())
# Out:
# When an instance of Book is created with the title 'The Great Gatsby', this message is printed.
# When an instance of Book is created with the title 'Advanced Mathematics', this message is printed.
# When an instance of Book is created with the title 'unknown', this message is printed.
# The Great Gatsby
# 1984

# %%
class Product:
    def __init__(self,name,price=0):
        self.name = name
        self.price = price

# %%
class Player:
    def __init__(self,x,y):
        self.x = x
        self.y = y
player=Player(10,20)
attributes = ['x', 'y']
# for attribute in attributes:
#     delattr(player, attribute)
print(player.x)
print(player.y)
# Out:
# 10
# 20

# %%
class Animal:
    def __init__(self,species,age):
        self.species=species
        self.age=age
dog=Animal("Golden Retriever",13)
print(dog.species)
dog.species="Labrador"
print(dog.species)
# Out:
# Golden Retriever

# %% [markdown]
# Class Attributes vs. Instance Attributes
#
# Let's review key differences between class attributes and instance attributes:
#
# ◼️ Class Attributes
# They belong to the class itself.
#
# Changing their value affects all the instances of the class because they take the value from the same source.
#
# ◼️ Instance Attributes
# They belong to the instances.
#
# Every instance has its own, independent, copy of the attribute.
#
# Changing their value only affects a particular instance. Other instances are not modified.

# %%
class BasketballPlayer:
    
    Team_name="Lakers"
    
    def __init__(self,position,height,weight,OVR):
        self.position=position
        self.height=height
        self.weight=weight
        self.OVR=OVR

Lebron=BasketballPlayer("SF","6'9",250,92)
print(Lebron.Team_name)
# Out:
# Lakers
